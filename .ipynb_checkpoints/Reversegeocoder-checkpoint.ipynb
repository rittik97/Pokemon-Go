# %%
import pandas as pd
import numpy as np
import requests
import sys

# %%
data=pd.read_csv('data/another.csv')
data.head(10)
# Out:
#    Unnamed: 0  key_0  Unnamed: 0.1  pokedex_id   latitude   longitude  \
# 0           0      0             0          16  20.525745  -97.460829
# 1           1      1             1         133  20.523695  -97.461167
# 2           2      2             2          16  38.903590  -77.199780
# 3           3      3             3          13  47.665903 -122.312561
# 4           4      4             4         133  47.666454 -122.311628
# 5           5      5             5          21 -31.954980  115.853609
# 6           6      6             6          66 -31.954245  115.852038
# 7           7      7             7          27  26.235257  -98.197591
# 8           8      8             8          35  20.525554  -97.458800
# 9           9      9             9          19  32.928558  -84.340278
#
#    close_to_water         city       weather  temperature  ...  defense   hp  \
# 0           False  Mexico_City         Foggy         25.5  ...       85   73
# ...

# %%
newdata.head()
# Out:
#    pokedex_id   latitude   longitude  close_to_water         city  \
# 0          16  20.525745  -97.460829           False  Mexico_City
# 1         133  20.523695  -97.461167           False  Mexico_City
# 2          16  38.903590  -77.199780           False     New_York
# 3          13  47.665903 -122.312561            True  Los_Angeles
# 4         133  47.666454 -122.311628            True  Los_Angeles
#
#         weather  temperature  population_density   id    name  ...  flee  \
# 0         Foggy         25.5           2431.2341   16  Pidgey  ...   20%
# 1         Foggy         25.5           2431.2341  133   Eevee  ...   10%
# 2         Clear         24.2            761.8856   16  Pidgey  ...   20%
# 3  PartlyCloudy         15.6           4842.1626   13  Weedle  ...   20%
# 4  PartlyCloudy         15.6           4842.1626  133   Eevee  ...   10%
#
#    candy       day    type morning afternoon  night           types  \
# ...

# %%
newdata.drop(['latlng_t'], axis=1, inplace=True)

# %%
newdata.to_csv('final.csv')

# %%
loc_data=pd.read_csv('data/loc.csv')

# %%
newdata=pd.merge(left=data, right=loc_data, how='left', left_on=data.latlng_t, right_on=loc_data.key)

# %%
loc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11427 entries, 0 to 11426
# Data columns (total 4 columns):
# key          11427 non-null object
# types        11427 non-null object
# level_one    11427 non-null object
# level_two    11427 non-null object
# dtypes: object(4)
# memory usage: 357.2+ KB

# %%
len(data.latlng_t.unique())#/len(data)
# Out:
# 11452

# %%
data.latlng_t.head()
# Out:
# 0     20.52,-97.46
# 1     20.52,-97.46
# 2     38.90,-77.19
# 3    47.66,-122.31
# 4    47.66,-122.31
# Name: latlng_t, dtype: object

# %%
np.unique(data['latlng_two'])[0:10]

# %%
lat_temp=str(data['latitude'].values[0]).split('.')
lat_temp[0]+'.'+lat_temp[1][:2]

# %%
def f(x):
    lat_temp=str(x['latitude']).split('.')
    lat_temp=lat_temp[0]+'.'+lat_temp[1][:2]
    long_temp=str(x['longitude']).split('.')
    long_temp=long_temp[0]+'.'+long_temp[1][:2]
    
    return lat_temp+','+long_temp

data['latlng_t']=data.apply(f, axis=1)

# %%
try:
        response = requests.get(
        'https://maps.googleapis.com/maps/api/geocode/json',
        params={'latlng': '-0.12,-78.49','key':"AIzaSyBmNUQfAqXz8z1wxxg8PqcBrC94VUIIwmI" },
        )
        types=response.json()['results'][0]['types'][0]
        level_one=response.json()['results'][0]['address_components'][2]['long_name']
        for i in response.json()['results'][0]['address_components']:
            if i['types'][0]=='administrative_area_level_1':
                level_two=(i['long_name'])

        d.append({'key':ltlng,
                 'types':types,
                 'level_one':level_one,
                 'level_two':level_two

                 },ignore_index=True)
        if idx%10==0:
            print(idx)
except Exception as e:
        print(e)
        exc_type, exc_obj, exc_tb = sys.exc_info()
        print(idx, exc_type, ltlng, exc_tb.tb_lineno)
# Out:
# name 'd' is not defined
# 8 <class 'NameError'> -0.22,-78.50 12

# %%
d[:-1]

# %%
len(np.unique(data['latlng_t'].values))
# Out:
# 11452

# %%
np.unique(data['latlng_t'].values)
# Out:
# array(['-0.12,-78.49', '-0.12,-78.50', '-0.16,-78.48', ..., '7.60,100.05',
#        '7.61,100.06', '9.90,-83.98'], dtype=object)

# %%
d=[]
for idx, ltlng in enumerate(np.unique(data['latlng_t'].values)):
    
    try:
        response = requests.get(
        'https://maps.googleapis.com/maps/api/geocode/json',
        params={'latlng': ltlng,'key':"AIzaSyBmNUQfAqXz8z1wxxg8PqcBrC94VUIIwmI" },
        )
        types=response.json()['results'][0]['types'][0]
        level_one=response.json()['results'][0]['address_components'][2]['long_name']
        for i in response.json()['results'][0]['address_components']:
            if i['types'][0]=='administrative_area_level_1':
                level_two=(i['long_name'])

        d.append({'key':ltlng,
                 'types':types,
                 'level_one':level_one,
                 'level_two':level_two

                 })
        if idx%10==0:
            print(idx)
    except Exception as e:
        exc_type, exc_obj, exc_tb = sys.exc_info()
        print(idx, exc_type, ltlng, exc_tb.tb_lineno)
# Out:
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 85 <class 'IndexError'> -22.89,-43.21 10
# 90
# 100
# 110
# 120
# 130
# 140
# 150
# 160
# 170
# 180
# 190
# 200
# 210
# 220
# 230
# 240
# 250
# 260
# 270
# 280
# 290
# 300
# 310
# 320
# 330
# 340
# 350
# 360
# 370
# 380
# 390
# 400
# 410
# 420
# 430
# 440
# 450
# 460
# 470
# 480
# 490
# 500
# 510
# 520
# 530
# 540
# 550
# 560
# 570
# 580
# 590
# 600
# 610
# 620
# 630
# 640
# 650
# 655 <class 'IndexError'> 13.46,144.75 10
# 660
# 670
# 680
# 690
# 700
# 710
# 720
# 730
# 740
# 750
# 760
# 770
# 780
# 790
# 800
# 810
# 820
# 830
# 840
# 850
# 860
# 870
# 880
# 890
# 900
# 910
# 920
# 930
# 940
# 950
# 960
# 970
# 980
# 990
# 1000
# 1010
# 1020
# 1030
# 1040
# 1050
# 1060
# 1070
# 1080
# 1084 <class 'IndexError'> 22.24,114.18 10
# 1090
# 1099 <class 'IndexError'> 22.30,114.15 10
# 1100
# 1110
# 1118 <class 'IndexError'> 22.54,120.34 10
# 1120
# 1130
# 1140
# 1150
# 1160
# 1170
# ...

# %%
d=pd.DataFrame(d)
# Out:
#                 key           types                 level_one  \
# 0      -0.12,-78.49  street_address                El Rosario
# 1      -0.12,-78.50  street_address                Cotocollao
# 2      -0.16,-78.48  street_address                   El Inca
# 3      -0.16,-78.49  street_address                Chaupicruz
# 4      -0.21,-78.48   establishment                     Quito
# ...             ...             ...                       ...
# 11422   68.43,17.42  street_address                    Narvik
# 11423   68.43,17.43  street_address                    Narvik
# 11424   7.60,100.05           route  Amphoe Muang Phatthalung
# 11425   7.61,100.06  street_address        Tambon Khuha Sawan
# 11426   9.90,-83.98   establishment      Provincia de Cartago
#
#                    level_two
# 0                  Pichincha
# 1                  Pichincha
# 2                  Pichincha
# 3                  Pichincha
# 4                  Pichincha
# ...                      ...
# ...

# %%
len(np.unique(d['level_one']))
# Out:
# 4819

# %%
d.to_csv('data/loc.csv',index=False)
